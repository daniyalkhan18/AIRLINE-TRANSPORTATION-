# %%
import networkx as nx
import matplotlib.pylab as pit
g=nx.read_edgelist("ibad.txt")
print(nx.info(g))
nx.draw_circular(g)
pit.show()
# Out:
# Name:
# Type: Graph
# Number of nodes: 34
# Number of edges: 65
# Average degree:   3.8235

# %%
import networkx as nx
import matplotlib.pylab as pit
g=nx.read_edgelist("ibad.txt")
print(nx.info(g))
nx.draw(g)
pit.show()
# Out:
# Name:
# Type: Graph
# Number of nodes: 34
# Number of edges: 65
# Average degree:   3.8235
